# %%
a=float(5)
print(a)
# Out:
# 5.0

# %%
a=str(5)
print(a)
# Out:
# 5

# %%
a=bool(5)
print(a)
# Out:
# True

# %%
a=complex(5)
print(a)
# Out:
# (5+0j)

# %%
k=int(5.6)
print(k)
# Out:
# 5

# %%
k=str(5.6)
print(k)
# Out:
# 5.6

# %%
k=bool(5.6)
print(k)
# Out:
# True

# %%
k=complex(5.6)
print(k)
# Out:
# (5.6+0j)
