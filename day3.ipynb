# %%
text="unhappy" 
print(text.removeprefix("un"))
# Out:
# happy

# %%
text="banana"
print(text.rsplit("a"))
# Out:
# ['b', 'n', 'n', '']

# %%
text="python language"
print(text.title())
# Out:
# Python Language

# %%
text="banana"
print(text.swapcase())
# Out:
# BANANA

# %%
text="python"
print(text.find("t"))
# Out:
# 2
