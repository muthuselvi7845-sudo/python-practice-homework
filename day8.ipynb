# %%
L=[1,2,"hello",4.0,5,6,"welcome",8.5,9,"colour"]
L[2:6]=[3.0,"welcome",5]
print(L)
# Out:
# [1, 2, 3.0, 'welcome', 5, 'welcome', 8.5, 9, 'colour']

# %%
L.pop()
print(L)
# Out:
# [1, 2, 3.0, 'welcome', 5, 'welcome', 8.5, 9]

# %%
L1=[1,2,"hello",4.0,5,6,"welcome",8.5,9,"colour"]
L2=[11,"everybody"]
L1.extend(L2)
print(L1)
# Out:
# [1, 2, 'hello', 4.0, 5, 6, 'welcome', 8.5, 9, 'colour', 11, 'everybody']

# %%
L=[1,2,"hello",4.0,5,6,"welcome",8.5,9,"colour"]
L.pop(2)
print(L)
# Out:
# [1, 2, 4.0, 5, 6, 'welcome', 8.5, 9, 'colour']
