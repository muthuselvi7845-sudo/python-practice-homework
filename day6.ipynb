# %%
skill=input("Enter your language:")
experience=input("Enter your experience:")
location=input("Enter your location:")

if (skill=="python" and experience=="1 year" and location=="chennai"):
    print("Infosys")

elif(skill=="python" and experience=="fresher" and location=="coimbatore"):
    print("Wipro")

elif(skill=="java" and experience=="fresher" and location=="chennai"):
    print("TCS")

elif(skill=="java" and experience=="1 year" and location=="bangalore"):
    print("Cognizant")

else:
    print("Rejected")
