# %%
x=10
y=3
print(x+y)
# Out:
# 13

# %%
x=10
y=3
print(x-y)
# Out:
# 7

# %%
x=10
y=3
print(x*y)
# Out:
# 30

# %%
x=10
y=3
print(x/y)
# Out:
# 3.3333333333333335

# %%
x=10
y=3
print(x%y)
# Out:
# 1

# %%
x=10
y=3
print(x**y)
# Out:
# 1000

# %%
x=10
y=3
print(x//y)
# Out:
# 3

# %%
#assignment operator
a=5
a+=2
print(a)
# Out:
# 7

# %%
a=5
a-=2
print(a)
# Out:
# 3

# %%
a=5
a*=2
print(a)
# Out:
# 10

# %%
a=5
a/=2
print(a)
# Out:
# 2.5

# %%
a=5
a**=2
print(a)
# Out:
# 25

# %%
a=5
a%=2
print(a)
# Out:
# 1

# %%
a=5
a//=2
print(a)
# Out:
# 2

# %%
#comparison operator
a=5
b=10
print(a>b)
# Out:
# False

# %%
a=5
b=10
print(a<b)
# Out:
# True

# %%
a=5
b=10
print(a>=b)
# Out:
# False

# %%
a=5
b=10
print(a<=b)
# Out:
# True

# %%
a=5
b=10
print(a==b)
# Out:
# False
