# %%
print(6 & 3)
# Out:
# 2

# %%
print(6 ^ 3)
# Out:
# 5

# %%
print(~5)
# Out:
# -6

# %%
a=5
b=6
print(a^b)
# Out:
# 3

# %%
a=4
b=3
print(a|b)
# Out:
# 7

# %%
a=5
b=6
c=(a ^ b)
print(bin(c))
# Out:
# 0b11
