# %%
L=[1,2,3,4,3,2,1,2,5]
unique_list=[]
for i in L:
    if i not in unique_list:
        unique_list.append(i)
print(unique_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
L=[1,2,3,4,3,2,1,2,5]
d={}
for i in L:
    if i in d:
        d[i]+=1
    else:
        d[i]=1
print(d)
# Out:
# {1: 2, 2: 3, 3: 2, 4: 1, 5: 1}
