# %%
name="Muthu"
print("Name:",name)
# Out:
# Name: Muthu

# %%
import sys
sys.version
# Out:
# '3.14.2 (tags/v3.14.2:df79316, Dec  5 2025, 17:18:21) [MSC v.1944 64 bit (AMD64)]'

# %%
height=5.6
print("Height:",height)
# Out:
# Height: 5.6

# %%
age=20
print("Age:",age)
# Out:
# Age: 20

# %%
is_student=True
print("Is student:",is_student)
# Out:
# Is student: True

# %%
name1="sai"
name2="sri"
name=(name1+" "+name2)
print(name)
# Out:
# sai sri
